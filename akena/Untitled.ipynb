# %%
# If cv2 is not installed in the active notebook environment, run:
# !pip install opencv-python
import cv2

photo = cv2.imread("image2.jpg")

if photo is None:
    raise FileNotFoundError("Could not load image2.jpg. Make sure it is in the same folder as this notebook.")

print(f"Image loaded successfully: {photo.shape[1]} x {photo.shape[0]} pixels")
# Out:
# Image loaded successfully: 2560 x 1440 pixels
